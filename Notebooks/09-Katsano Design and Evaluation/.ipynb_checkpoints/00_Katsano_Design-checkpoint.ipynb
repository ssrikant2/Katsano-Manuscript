# %%
import pandas as pd
import numpy as np
from upsetplot import plot
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import seaborn as sns
import random
import gpplot as gpp
from zipfile import ZipFile
gpp.set_aesthetics(context = 'paper')

# %% [markdown]
# Includes transcript selection, CRISPick run inputs, assessment of library properties, and formatting of 6 column file for clone pool order.

# %% [markdown]
# ### Transcript Selection

# %%
#read in transcript annotations
zip_file = ZipFile('../../Data/GENCODE48/gencode_48_protein_coding_transcripts.csv.zip')
protein_coding_transcripts = pd.read_csv(zip_file.open('gencode_48_protein_coding_transcripts.csv'))
protein_coding_transcripts
# Out:
#              seqid   source        type   start     end score strand phase  \
# 0             chr1   HAVANA  transcript   65419   71585     .      +     .
# 1             chr1   HAVANA  transcript  450740  451678     .      -     .
# 2             chr1   HAVANA  transcript  685716  686654     .      -     .
# 3             chr1   HAVANA  transcript  923923  944574     .      +     .
# 4             chr1   HAVANA  transcript  923923  944574     .      +     .
# ...            ...      ...         ...     ...     ...   ...    ...   ...
# 171904  KI270731.1  ENSEMBL  transcript   10598   13001     .      -     .
# 171905  KI270734.1  ENSEMBL  transcript   72411   74814     .      +     .
# 171906  KI270734.1  ENSEMBL  transcript  131494  137392     .      +     .
# 171907  KI270734.1  ENSEMBL  transcript  138082  161750     .      -     .
# 171908  KI270734.1  ENSEMBL  transcript  138082  161852     .      -     .
#
# ...

# %%
#select Ensembl Canonical transcripts
ensembl_canonical_transcripts = protein_coding_transcripts[protein_coding_transcripts['tag'].str.contains('Ensembl_canonical')].copy()
ensembl_canonical_transcripts
# Out:
#              seqid   source        type    start      end score strand phase  \
# 0             chr1   HAVANA  transcript    65419    71585     .      +     .
# 1             chr1   HAVANA  transcript   450740   451678     .      -     .
# 2             chr1   HAVANA  transcript   685716   686654     .      -     .
# 3             chr1   HAVANA  transcript   923923   944574     .      +     .
# 18            chr1   HAVANA  transcript   944203   959256     .      -     .
# ...            ...      ...         ...      ...      ...   ...    ...   ...
# 171903  KI270728.1  ENSEMBL  transcript  1270984  1271271     .      +     .
# 171904  KI270731.1  ENSEMBL  transcript    10598    13001     .      -     .
# 171905  KI270734.1  ENSEMBL  transcript    72411    74814     .      +     .
# 171906  KI270734.1  ENSEMBL  transcript   131494   137392     .      +     .
# 171908  KI270734.1  ENSEMBL  transcript   138082   161852     .      -     .
#
# ...

# %%
#read in illumina-selected transcripts, reformat to be compatible with gencode file
illumina_tss_df = pd.read_table('../../Data/Katsano/CAGE_tss.tsv')
illumina_tss_df['transcript_id_version'] = illumina_tss_df['transcript_id']
illumina_tss_df = illumina_tss_df.drop('transcript_id',axis=1)
illumina_tss_df['transcript_id_without_version'] = illumina_tss_df['transcript_id_version'].str.split('.', expand=True)[0]
illumina_tss_df['strand'] = np.where(illumina_tss_df['strand'] == 1, '+', '-')
illumina_tss_df
# Out:
#       chrom   tss_pos strand    gene                gene_id  \
# 0      chr1     65418      +   OR4F5        ENSG00000186092
# 1      chr1    451677      -  OR4F29        ENSG00000284733
# 2      chr1    686653      -  OR4F16        ENSG00000284662
# 3      chr1    923922      +  SAMD11        ENSG00000187634
# 4      chr1    959255      -   NOC2L        ENSG00000188976
# ...     ...       ...    ...     ...                    ...
# 19680  chrY  25044022      -   BPY2C        ENSG00000185894
# 19681  chrY  25622161      +    CDY1        ENSG00000172288
# 19682  chrY  57067864      +   VAMP7  ENSG00000124333_PAR_Y
# 19683  chrY  57184215      +    IL9R  ENSG00000124334_PAR_Y
# 19684  chrY  57207480      +  WASH6P  ENSG00000182484_PAR_Y
#
#           transcript_id_version transcript_id_without_version
# 0             ENST00000641515.2               ENST00000641515
# 1             ENST00000426406.4               ENST00000426406
# ...

# %%
#select illumina transcripts still present in GENCODE v48
illumina_transcripts = protein_coding_transcripts[protein_coding_transcripts['ID'].isin(illumina_tss_df['transcript_id_version'])].copy()
noncanonical_illumina = illumina_transcripts[~illumina_transcripts['ID'].isin(ensembl_canonical_transcripts['ID'])].copy()

# %%
#merge illumina df with gencode protein-coding df on transcript id without version
merged_df = protein_coding_transcripts.merge(illumina_tss_df,
                                             left_on = ['seqid','strand','transcript_id_without_version'],
                                             right_on = ['chrom','strand','transcript_id_without_version'],
                                             how = 'inner')

merged_df = merged_df.rename(columns = {'gene_id_y':'gene_id_illumina','gene_id_x':'gene_id_gencode48',
                                        'transcript_id_version':'transcript_id_version_illumina',
                                        'ID':'transcript_id_version_gencode48',
                                        'gene':'gene_symbol_illumina','gene_name':'gene_symbol_gencode48',
                                        'TSS':'tss_gencode48'})
merged_df
# Out:
#       seqid   source        type     start       end score strand phase  \
# 0      chr1   HAVANA  transcript     65419     71585     .      +     .
# 1      chr1   HAVANA  transcript    450740    451678     .      -     .
# 2      chr1   HAVANA  transcript    685716    686654     .      -     .
# 3      chr1   HAVANA  transcript    923923    944574     .      +     .
# 4      chr1   HAVANA  transcript    944203    959256     .      -     .
# ...     ...      ...         ...       ...       ...   ...    ...   ...
# 19547  chrY  ENSEMBL  transcript  24626085  24632010     .      +     .
# 19548  chrY   HAVANA  transcript  24763069  24813393     .      -     .
# 19549  chrY   HAVANA  transcript  24833919  24907040     .      +     .
# 19550  chrY  ENSEMBL  transcript  25038098  25044023     .      -     .
# 19551  chrY   HAVANA  transcript  25622117  25624902     .      +     .
#
#                                               attributes  \
# ...

# %%
#illumina tss is one off from gencode
(merged_df['tss_pos'] - merged_df['tss_gencode48']).value_counts()
# Out:
# -1      19305
# -568        5
#  18         4
#  4          4
# -3          4
#         ...
#  152        1
# -63         1
# -42         1
# -56         1
#  59         1
# Length: 180, dtype: int64

# %%
#shift illumina tss to match gencode
merged_df['tss_illumina'] = merged_df['tss_pos'] + 1

# %%
#find transcripts that have been updated
updated_transcripts = merged_df[merged_df['transcript_id_version_illumina'] != merged_df['transcript_id_version_gencode48']].copy()

#subset to those with unchanged tss
same_tss_updated_transcripts = updated_transcripts[updated_transcripts['tss_illumina'] == updated_transcripts['tss_gencode48']].copy()

#get the same transcript rows in the original dataframe so the columns match already selected transcripts
same_tss_updated_transcripts = protein_coding_transcripts[protein_coding_transcripts['ID'].isin(same_tss_updated_transcripts['transcript_id_version_gencode48'])].copy()

same_tss_updated_transcripts
# Out:
#         seqid  source        type     start       end score strand phase  \
# 1989     chr1  HAVANA  transcript  19975435  19979618     .      -     .
# 2309     chr1  HAVANA  transcript  23309853  23344281     .      -     .
# 4370     chr1  HAVANA  transcript  42463286  42657190     .      +     .
# 5278     chr1  HAVANA  transcript  46632737  46668364     .      -     .
# 6710     chr1  HAVANA  transcript  77779649  77879540     .      +     .
# ...       ...     ...         ...       ...       ...   ...    ...   ...
# 164819  chr22  HAVANA  transcript  39960397  39964905     .      +     .
# 165564  chr22  HAVANA  transcript  49991811  50012659     .      -     .
# 165831  chr22  HAVANA  transcript  50674892  50733212     .      +     .
# 166270   chrX  HAVANA  transcript  13770939  13938638     .      -     .
# 166758   chrX  HAVANA  transcript  26160601  26162410     .      +     .
#
#                                                attributes                 ID  \
# ...

# %%
#subset to illumina-selected transcripts which aren't in gencode v48 and also haven't been selected already
illumina_not_in_gencode48 = illumina_tss_df[~illumina_tss_df['transcript_id_version'].isin(protein_coding_transcripts['ID']) &
                                            ~illumina_tss_df['transcript_id_without_version'].isin(same_tss_updated_transcripts['transcript_id_without_version'])]

#merge on chromosome and strand only to get all other transcripts on same chromosome+strand that are in gencode v48
chrom_strand_merged_df = protein_coding_transcripts.merge(illumina_not_in_gencode48,
                                                          left_on = ['seqid','strand'],
                                                          right_on = ['chrom','strand'],
                                                          how = 'inner')

chrom_strand_merged_df = chrom_strand_merged_df.rename(columns = {'gene_id_y':'gene_id_illumina',
                                                                  'gene_id_x':'gene_id_gencode48',
                                                                  'transcript_id_version':'transcript_id_version_illumina',
                                                                  'ID':'transcript_id_version_gencode48',
                                                                  'gene':'gene_symbol_illumina','gene_name':'gene_symbol_gencode48',
                                                                  'TSS':'tss_gencode48',
                                                                  'transcript_id_without_version_x':'transcript_id_gencode48',
                                                                  'transcript_id_without_version_y':'transcript_id_illumina'})

chrom_strand_merged_df['tss_illumina'] = chrom_strand_merged_df['tss_pos'] + 1

chrom_strand_merged_df
# Out:
#         seqid  source        type     start       end score strand phase  \
# 0        chr1  HAVANA  transcript     65419     71585     .      +     .
# 1        chr1  HAVANA  transcript     65419     71585     .      +     .
# 2        chr1  HAVANA  transcript     65419     71585     .      +     .
# 3        chr1  HAVANA  transcript     65419     71585     .      +     .
# 4        chr1  HAVANA  transcript     65419     71585     .      +     .
# ...       ...     ...         ...       ...       ...   ...    ...   ...
# 1501753  chrY  HAVANA  transcript  25043991  25062548     .      -     .
# 1501754  chrY  HAVANA  transcript  25043991  25062548     .      -     .
# 1501755  chrY  HAVANA  transcript  25043991  25062548     .      -     .
# 1501756  chrY  HAVANA  transcript  25043991  25062548     .      -     .
# 1501757  chrY  HAVANA  transcript  25043991  25062548     .      -     .
#
#                                                 attributes  \
# ...

# %%
#get one gencode v48 transcript per illumina transcript + gencode v48 gene with closest TSS
chrom_strand_merged_df['tss_diff'] = np.abs(chrom_strand_merged_df['tss_gencode48'] - chrom_strand_merged_df['tss_illumina'])
closest_transcript_idxs = chrom_strand_merged_df.groupby(['transcript_id_version_illumina','gene_id_gencode48'])['tss_diff'].idxmin()
closest_transcripts = chrom_strand_merged_df.loc[closest_transcript_idxs].copy()

#label whether the closest transcript for the given gene matches the gene/transcript id corresponding to the illumina transcript
closest_transcripts['same_gene_symbol'] = (closest_transcripts['gene_symbol_illumina'] == closest_transcripts['gene_symbol_gencode48'])
closest_transcripts['same_gene_id'] = (closest_transcripts['gene_id_illumina'] == closest_transcripts['gene_id_gencode48'])
closest_transcripts['same_transcript_id'] = (closest_transcripts['transcript_id_illumina'] == closest_transcripts['transcript_id_gencode48'])
closest_transcripts
# Out:
#          seqid  source        type     start       end score strand phase  \
# 796190   chr11  HAVANA  transcript  64270269  64271868     .      -     .
# 763668   chr11  HAVANA  transcript   3360385   3362720     .      -     .
# 775344   chr11  HAVANA  transcript  17392979  17394997     .      -     .
# 775876   chr11  HAVANA  transcript  17493900  17495093     .      -     .
# 779740   chr11  HAVANA  transcript  31793173  31794126     .      -     .
# ...        ...     ...         ...       ...       ...   ...    ...   ...
# 1497951   chrY  HAVANA  transcript    630791    651584     .      +     .
# 1497979   chrY  HAVANA  transcript   1268793   1325373     .      +     .
# 1500359   chrY  HAVANA  transcript  57067865  57130289     .      +     .
# 1500499   chrY  HAVANA  transcript  57207346  57208935     .      +     .
# 1500443   chrY  HAVANA  transcript  57184216  57197337     .      +     .
#
#                                                 attributes  \
# ...

# %%
#subset to those associated with the same gene; allow for the same gene symbol, gene id, or transcript id since nomenclature has changed over time
same_gene_closest_transcripts = closest_transcripts[closest_transcripts['same_gene_symbol'] | closest_transcripts['same_gene_id'] |
                                                    closest_transcripts['same_transcript_id']].copy()

same_gene_closest_transcripts = protein_coding_transcripts[protein_coding_transcripts['ID'].isin(same_gene_closest_transcripts['transcript_id_version_gencode48'])].copy()

same_gene_closest_transcripts
# Out:
#        seqid  source        type     start       end score strand phase  \
# 598     chr1  HAVANA  transcript   2636986   2801693     .      -     .
# 1502    chr1  HAVANA  transcript  13070774  13077884     .      +     .
# 1510    chr1  HAVANA  transcript  13222695  13226154     .      -     .
# 1511    chr1  HAVANA  transcript  13254198  13263435     .      +     .
# 1513    chr1  HAVANA  transcript  13281304  13285137     .      -     .
# ...      ...     ...         ...       ...       ...   ...    ...   ...
# 171805  chrY  HAVANA  transcript  22403461  22417881     .      +     .
# 171841  chrY  HAVANA  transcript  25622162  25624338     .      +     .
# 171842  chrY  HAVANA  transcript  57067865  57130289     .      +     .
# 171848  chrY  HAVANA  transcript  57184216  57197337     .      +     .
# 171853  chrY  HAVANA  transcript  57207481  57211894     .      +     .
#
#                                                attributes                 ID  \
# ...

# %% [markdown]
# ### Combine Selected Transcripts

# %%
#add column to each set of selected transcripts to indicate why/when it was selected

ensembl_canonical_transcripts['Selection Category'] = 'Ensembl Canonical'
illumina_transcripts['Selection Category'] = 'Illumina Selected'
same_tss_updated_transcripts['Selection Category'] = 'Illumina Selected (transcript version updated but TSS unchanged)'
same_gene_closest_transcripts['Selection Category'] = 'Closest to Illumina Selected'

# %%
#dropping duplicates only according to gene and tss coordinates allows duplicate TSSs to be dropped even though
    #they have a different value for "Selection Category" and potentially a different value for "transcript_id"
    #by default, the first duplicate is kept
selected_transcripts_combined = pd.concat([ensembl_canonical_transcripts,illumina_transcripts,
                                           same_tss_updated_transcripts,same_gene_closest_transcripts]).drop_duplicates(subset=['gene_id',
                                                                                                                                'seqid',
                                                                                                                                'strand',
                                                                                                                                'TSS'])
selected_transcripts_combined
# Out:
#        seqid  source        type     start       end score strand phase  \
# 0       chr1  HAVANA  transcript     65419     71585     .      +     .
# 1       chr1  HAVANA  transcript    450740    451678     .      -     .
# 2       chr1  HAVANA  transcript    685716    686654     .      -     .
# 3       chr1  HAVANA  transcript    923923    944574     .      +     .
# 18      chr1  HAVANA  transcript    944203    959256     .      -     .
# ...      ...     ...         ...       ...       ...   ...    ...   ...
# 171563  chrY  HAVANA  transcript    303346    318798     .      -     .
# 171591  chrY  HAVANA  transcript   1268830   1309924     .      +     .
# 171623  chrY  HAVANA  transcript   1615164   1643027     .      +     .
# 171805  chrY  HAVANA  transcript  22403461  22417881     .      +     .
# 171841  chrY  HAVANA  transcript  25622162  25624338     .      +     .
#
#                                                attributes                 ID  \
# ...

# %%
selected_transcripts_combined['transcript_type'].value_counts()
# Out:
# protein_coding                    21673
# nonsense_mediated_decay             323
# protein_coding_LoF                   50
# retained_intron                      23
# protein_coding_CDS_not_defined       16
# non_stop_decay                        1
# Name: transcript_type, dtype: int64

# %%
#check which transcript types lack a protein id
selected_transcripts_combined.loc[selected_transcripts_combined['protein_id'].isna(),'transcript_type'].value_counts()
# Out:
# retained_intron                   23
# protein_coding_CDS_not_defined    16
# Name: transcript_type, dtype: int64

# %%
#remove transcripts that don't code for a protein
selected_transcripts_protein_coding = selected_transcripts_combined[~selected_transcripts_combined['protein_id'].isna()]
selected_transcripts_protein_coding
# Out:
#        seqid  source        type      start        end score strand phase  \
# 0       chr1  HAVANA  transcript      65419      71585     .      +     .
# 1       chr1  HAVANA  transcript     450740     451678     .      -     .
# 2       chr1  HAVANA  transcript     685716     686654     .      -     .
# 3       chr1  HAVANA  transcript     923923     944574     .      +     .
# 18      chr1  HAVANA  transcript     944203     959256     .      -     .
# ...      ...     ...         ...        ...        ...   ...    ...   ...
# 170804  chrX  HAVANA  transcript  152708264  152709265     .      -     .
# 171563  chrY  HAVANA  transcript     303346     318798     .      -     .
# 171591  chrY  HAVANA  transcript    1268830    1309924     .      +     .
# 171623  chrY  HAVANA  transcript    1615164    1643027     .      +     .
# 171841  chrY  HAVANA  transcript   25622162   25624338     .      +     .
#
#                                                attributes                 ID  \
# ...

# %%
#transcripts per gene?
selected_transcripts_protein_coding['gene_id'].value_counts().value_counts()
# Out:
# 1    18195
# 2     1923
# 3        2
# Name: gene_id, dtype: int64

# %%
#which genes have three target transcripts?
transcript_per_gene = selected_transcripts_protein_coding['gene_id'].value_counts()
three_transcript_genes = transcript_per_gene.index[transcript_per_gene == 3].tolist()
selected_transcripts_protein_coding[selected_transcripts_protein_coding['gene_id'].isin(three_transcript_genes)]
# Out:
#         seqid  source        type     start       end score strand phase  \
# 82594   chr10  HAVANA  transcript  49988406  50010499     .      +     .
# 157424  chr20  HAVANA  transcript  10401009  10434222     .      -     .
# 82593   chr10  HAVANA  transcript  49988368  50009348     .      +     .
# 157425  chr20  HAVANA  transcript  10401621  10434214     .      -     .
# 82596   chr10  HAVANA  transcript  49988716  50010476     .      +     .
# 157427  chr20  HAVANA  transcript  10405184  10431922     .      -     .
#
#                                                attributes                  ID  \
# 82594   ID=ENST00000412531.7;Parent=ENSG00000204149.16...   ENST00000412531.7
# 157424  ID=ENST00000347364.7;Parent=ENSG00000125863.20...   ENST00000347364.7
# 82593   ID=ENST00000679810.1;Parent=ENSG00000204149.16...   ENST00000679810.1
# 157425  ID=ENST00000651692.1;Parent=ENSG00000125863.20...   ENST00000651692.1
# ...

# %%
#why do these genes have an extra transcript selected?
same_gene_closest_transcripts = closest_transcripts[closest_transcripts['same_gene_symbol'] | closest_transcripts['same_gene_id'] |
                                                    closest_transcripts['same_transcript_id']].copy()
same_gene_closest_transcripts[same_gene_closest_transcripts['transcript_id_version_gencode48'] == 'ENST00000311652.11']
# Out:
#         seqid  source        type     start       end score strand phase  \
# 739814  chr10  HAVANA  transcript  49988716  50010476     .      +     .
#
#                                                attributes  \
# 739814  ID=ENST00000311652.11;Parent=ENSG00000204149.1...
#
#        transcript_id_version_gencode48  ...   tss_pos gene_symbol_illumina  \
# 739814              ENST00000311652.11  ...  49988749        TIMM23B-AGAP6
#
#        gene_id_illumina transcript_id_version_illumina transcript_id_illumina  \
# 739814  ENSG00000178440             ENST00000311652.10        ENST00000311652
#
#        tss_illumina tss_diff same_gene_symbol  same_gene_id  \
# 739814     49988750       34            False         False
#
#         same_transcript_id
# 739814                True
#
# [1 rows x 39 columns]

# %%
#ENST00000311652 was included in the Illumina-selected set as a fusion transcript corresponding to TIMM23B-AGAP6 but is now associated with AGAP6 only
illumina_tss_df[illumina_tss_df['gene'].str.contains('AGAP6')]
# Out:
#       chrom   tss_pos strand           gene          gene_id  \
# 2238  chr10  49988367      +          AGAP6  ENSG00000204149
# 2239  chr10  49988749      +  TIMM23B-AGAP6  ENSG00000178440
#
#      transcript_id_version transcript_id_without_version
# 2238     ENST00000679810.1               ENST00000679810
# 2239    ENST00000311652.10               ENST00000311652

# %%
#MKKS used to have three different gene ids
illumina_tss_df[illumina_tss_df['gene'].str.contains('MKKS')]
# Out:
#        chrom   tss_pos strand  gene          gene_id transcript_id_version  \
# 11595  chr20  10420736      -  MKKS  ENSG00000285723     ENST00000649912.1
# 11596  chr20  10431921      -  MKKS  ENSG00000285508     ENST00000609375.1
# 11597  chr20  10434213      -  MKKS  ENSG00000125863     ENST00000651692.1
#
#       transcript_id_without_version
# 11595               ENST00000649912
# 11596               ENST00000609375
# 11597               ENST00000651692

# %%
#now only has one
selected_transcripts_protein_coding[selected_transcripts_protein_coding['gene_name'] == 'MKKS']['gene_id']
# Out:
# 157424    ENSG00000125863.20
# 157425    ENSG00000125863.20
# 157427    ENSG00000125863.20
# Name: gene_id, dtype: object

# %%
#make sure there are no duplicates transcripts
selected_transcripts_protein_coding['ID'].value_counts().value_counts()
# Out:
# 1    22047
# Name: ID, dtype: int64

# %%
selected_transcripts_protein_coding['gene_id'].nunique()
# Out:
# 20120

# %%
selected_transcripts_protein_coding['Selection Category'].value_counts()
# Out:
# Ensembl Canonical                                                   20120
# Illumina Selected                                                    1820
# Closest to Illumina Selected                                           82
# Illumina Selected (transcript version updated but TSS unchanged)       25
# Name: Selection Category, dtype: int64

# %%
1820+82+25
# Out:
# 1927

# %%
selected_transcripts_protein_coding.to_csv('../../Data/Katsano/katsano_selected_transcripts.txt', index = False)

# %%
selected_transcripts_protein_coding = pd.read_csv('../../Data/Katsano/katsano_selected_transcripts.txt')
selected_transcripts_protein_coding
# Out:
#       seqid  source        type      start        end score strand phase  \
# 0      chr1  HAVANA  transcript      65419      71585     .      +     .
# 1      chr1  HAVANA  transcript     450740     451678     .      -     .
# 2      chr1  HAVANA  transcript     685716     686654     .      -     .
# 3      chr1  HAVANA  transcript     923923     944574     .      +     .
# 4      chr1  HAVANA  transcript     944203     959256     .      -     .
# ...     ...     ...         ...        ...        ...   ...    ...   ...
# 22042  chrX  HAVANA  transcript  152708264  152709265     .      -     .
# 22043  chrY  HAVANA  transcript     303346     318798     .      -     .
# 22044  chrY  HAVANA  transcript    1268830    1309924     .      +     .
# 22045  chrY  HAVANA  transcript    1615164    1643027     .      +     .
# 22046  chrY  HAVANA  transcript   25622162   25624338     .      +     .
#
#                                               attributes                 ID  \
# ...

# %% [markdown]
# ### Format CRISPick Input

# %%
selected_transcripts_protein_coding['coordinates'] = (selected_transcripts_protein_coding['seqid'] + ':' +
                                                      selected_transcripts_protein_coding['strand'] + ':' +
                                                      selected_transcripts_protein_coding['TSS'].astype(str))
selected_transcripts_protein_coding['coordinates'].drop_duplicates().to_csv('../../Data/Katsano/katsano_target_coordinates.txt',
                                                                            sep = '\n', index = False, header = None)

# %% [markdown]
# #### Run CRISPick with following inputs:
#
# Reference genome: Ensembl v.114\
# Mechanism: CRISPRi\
# Enzyme: SpyoCas9\
# On-Target Scorer: RS3i-Chen2013+ATAC\
# Off-Target Scorer: Seed Score v1\
# Targets: upload katsano_target_coordinates.txt\
# Library Mode (100 non-targeting, 900 intergenic, 0 positive controls/preselects)\
# Quota: 4\
# Target Local Mode

# %% [markdown]
# CRISPick does not recognize any identifiers for 4 of the coordinates (KI270721.1:+:2585, KI270734.1:+:72411, KI270734.1:+:131494, and KI270734.1:-:161852). These are therefore removed from the library.

# %%
#check why these transcripts were selected
selected_transcripts_protein_coding[selected_transcripts_protein_coding['coordinates'].isin(['KI270721.1:+:2585',
                                                                                             'KI270734.1:+:72411',
                                                                                             'KI270734.1:+:131494',
                                                                                             'KI270734.1:-:161852'])]

#all Ensembl Canonical
# Out:
#             seqid   source        type   start     end score strand phase  \
# 20106  KI270721.1  ENSEMBL  transcript    2585   11802     .      +     .
# 20117  KI270734.1  ENSEMBL  transcript   72411   74814     .      +     .
# 20118  KI270734.1  ENSEMBL  transcript  131494  137392     .      +     .
# 20119  KI270734.1  ENSEMBL  transcript  138082  161852     .      -     .
#
#                                               attributes                 ID  \
# 20106  ID=ENST00000612848.1;Parent=ENSG00000276345.1;...  ENST00000612848.1
# 20117  ID=ENST00000617983.1;Parent=ENSG00000276017.1;...  ENST00000617983.1
# 20118  ID=ENST00000613204.1;Parent=ENSG00000278817.1;...  ENST00000613204.1
# 20119  ID=ENST00000621424.4;Parent=ENSG00000277196.4;...  ENST00000621424.4
#
#        ...         protein_id                                      tag  \
# 20106  ...  ENSP00000478035.1  basic,Ensembl_canonical,GENCODE_Primary
# ...

# %% [markdown]
# ### Analysis of Library Properties

# %%
#read in crispick file
zip_file = ZipFile('../../Data/Katsano/katsano-sgrna-designs.txt.zip')
katsano_designs = pd.read_table(zip_file.open('katsano-sgrna-designs.txt'))
katsano_designs
# Out:
# /var/folders/mj/lhpd16ys0cx2wkbhm7s0nfcm0000gp/T/ipykernel_37170/1610091690.py:3: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   katsano_designs = pd.read_table(zip_file.open('katsano-sgrna-designs.txt'))
#                  Input  Quota  Target Taxon  Target Gene ID  \
# 0         chr1:+:65419    4.0          9606             NaN
# 1         chr1:+:65419    4.0          9606             NaN
# 2         chr1:+:65419    4.0          9606             NaN
# 3         chr1:+:65419    4.0          9606             NaN
# 4         chr1:+:65419    4.0          9606             NaN
# ...                ...    ...           ...             ...
# 1736036  (NEG_CONTROL)    NaN          9606             NaN
# 1736037  (NEG_CONTROL)    NaN          9606             NaN
# 1736038  (NEG_CONTROL)    NaN          9606             NaN
# 1736039  (NEG_CONTROL)    NaN          9606             NaN
# ...

# %%
#subset to picked guides
katsano_picked = katsano_designs[~katsano_designs['Pick Order'].isna()].copy()

#off-target hit columns get read in as strings, cast as ints
katsano_picked.loc[:,'Off-Target CFD100 Hits'] = katsano_picked['Off-Target CFD100 Hits'].astype(int)
katsano_picked.loc[:,'Off-Target Tier I CFD100 Hits'] = katsano_picked['Off-Target Tier I CFD100 Hits'].astype(int)

katsano_picked
# Out:
# /var/folders/mj/lhpd16ys0cx2wkbhm7s0nfcm0000gp/T/ipykernel_37170/1239959825.py:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   katsano_picked.loc[:,'Off-Target CFD100 Hits'] = katsano_picked['Off-Target CFD100 Hits'].astype(int)
# /var/folders/mj/lhpd16ys0cx2wkbhm7s0nfcm0000gp/T/ipykernel_37170/1239959825.py:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   katsano_picked.loc[:,'Off-Target Tier I CFD100 Hits'] = katsano_picked['Off-Target Tier I CFD100 Hits'].astype(int)
# ...

# %%
#total unique guides
katsano_picked['sgRNA Sequence'].nunique()
# Out:
# 84041

# %%
#number of NEW guides chosen in each picking round?
katsano_picked[['sgRNA Sequence','Picking Round']].sort_values(by = 'Picking Round').drop_duplicates('sgRNA Sequence')['Picking Round'].value_counts()
# Out:
# 1.0    72595
# 5.0     5223
# 4.0     2357
# 7.0     1011
# 2.0      937
# 3.0      867
# 9.0       28
# 6.0       22
# 8.0        1
# Name: Picking Round, dtype: int64

# %%
#RS3i score distribution
katsano_picked['On-Target Efficacy Score'].hist(bins=50)
# Out:
# <Axes: >

# %%
#label intergenic and non-targeting guides
katsano_picked['guide_group'] = np.where(katsano_picked['Input'] == '(NEG_CONTROL)','control','targeting')
katsano_picked.loc[(katsano_picked['guide_group'] == 'control') &
                   (katsano_picked['Off-Target CFD100 Hits'] == 1),'guide_group'] = 'intergenic'
katsano_picked.loc[(katsano_picked['guide_group'] == 'control') &
                   (katsano_picked['Off-Target CFD100 Hits'] == 0),'guide_group'] = 'non-targeting'

katsano_picked['guide_group'].value_counts()
# Out:
# targeting        87796
# intergenic         900
# non-targeting      100
# Name: guide_group, dtype: int64

# %%
plot_df = katsano_picked.groupby(['guide_group','Seed Score (v1)']).agg(num_guides = ('sgRNA Sequence','nunique')).reset_index()

plot_df['total_guides'] = plot_df.groupby('guide_group')['num_guides'].transform('sum')
plot_df['prop_guides'] = plot_df['num_guides']/plot_df['total_guides']
plot_df = plot_df.pivot(index = 'guide_group', columns = 'Seed Score (v1)', values = 'prop_guides')


#remove non-targeting
plot_df = plot_df[plot_df.index != 'non-targeting'].copy()

plot_df.plot(kind='bar', stacked=True, cmap = 'Reds')
plt.legend(title = 'Seed Score', bbox_to_anchor = [1,1])
plt.ylabel('Proportion of guides')
plt.xlabel('Guide Group')
plt.title('Original')

sns.despine()

# %% [markdown]
# Since original intergenic controls don't follow the same seed score distribution as targeting guides, resample them.

# %%
onesite_controls = pd.read_table('../../Data/CRISPickRuns/sgrna-negcontrols-onesite-9606-GRCh38-SpyoCas9-10000.txt',skiprows=1).rename(columns = {'sgRNA Seq':'sgRNA Sequence'})[['sgRNA Sequence']]

# %%
def count_overlapping_matches(seq,pattern):
    count = 0
    length = len(pattern)
    for i in range(len(seq)-1):
        if seq[i:(i+length)] == pattern:
            count +=1
    return count

# %%
#calculate seed scores for all controls to be sampled from
onesite_controls['seed_seq'] = onesite_controls['sgRNA Sequence'].str[-12:]
onesite_controls['Seed Score (v1)'] = onesite_controls['seed_seq'].apply(lambda seq: count_overlapping_matches(seq,'GG'))

# %%
num_onesite = 900

#get list of all targeting guide seed scores
targeting_seed_scores = katsano_picked.loc[katsano_picked['guide_group'] == 'targeting',
                                          ['sgRNA Sequence','Seed Score (v1)']].drop_duplicates()

#randomly sample number of intended onesite guides from targeting guides
sampled_seed_scores_num_onesite = random.sample(targeting_seed_scores['Seed Score (v1)'].tolist(),num_onesite)

selected_onesite_list = []

#loop through unique seed score values of targeting guides
unique_seed_scores = targeting_seed_scores['Seed Score (v1)'].unique().tolist()
for ss in unique_seed_scores:
    #subset controls to those with that particular seed score
    onesite_subset = onesite_controls.loc[onesite_controls['Seed Score (v1)'] == ss,'sgRNA Sequence'].tolist()

    #get the number of sampled targeting guides with that seed score
    num_sampled_onesite = sum([x==ss for x in sampled_seed_scores_num_onesite])

    #sample that number of guides from the control subsets
    selected_onesites = random.sample(onesite_subset,num_sampled_onesite)

    #add sampled controls to list
    selected_onesite_list = selected_onesite_list + selected_onesites

# %%
#include original nosites
katsano_nosites = katsano_picked.loc[katsano_picked['guide_group'] == 'non-targeting',['sgRNA Sequence']].reset_index(drop=True)
katsano_nosites['guide_group'] = 'non-targeting'

#format onesites into df
katsano_onesites = pd.DataFrame({'sgRNA Sequence':selected_onesite_list})
katsano_onesites['guide_group'] = 'intergenic'

katsano_controls = pd.concat([katsano_nosites,katsano_onesites])
katsano_controls['seed_seq'] = katsano_controls['sgRNA Sequence'].str[-12:]
katsano_controls['Seed Score (v1)'] = katsano_controls['seed_seq'].apply(lambda seq: count_overlapping_matches(seq,'GG'))

#subset df of targeting
katsano_targeting = katsano_picked[~katsano_picked['Picking Round'].isna()]

# %%
#katsano_controls[['sgRNA Sequence','guide_group']].to_csv('../../Data/Katsano/katsano_controls.txt',index=False,sep='\t')

# %%
katsano_controls = pd.read_table('../../Data/Katsano/katsano_controls.txt')
katsano_controls['seed_seq'] = katsano_controls['sgRNA Sequence'].str[-12:]
katsano_controls['Seed Score (v1)'] = katsano_controls['seed_seq'].apply(lambda seq: count_overlapping_matches(seq,'GG'))

new_katsano = pd.concat([katsano_targeting,katsano_controls]).reset_index(drop=True)

new_katsano['Seed Score (v1)'] = np.where(new_katsano['Seed Score (v1)'] >= 3, '>=3', new_katsano['Seed Score (v1)'])

plot_df = new_katsano.groupby(['guide_group','Seed Score (v1)']).agg(num_guides = ('sgRNA Sequence','nunique')).reset_index()

plot_df['total_guides'] = plot_df.groupby('guide_group')['num_guides'].transform('sum')
plot_df['prop_guides'] = plot_df['num_guides']/plot_df['total_guides']
plot_df = plot_df.pivot(index = 'guide_group', columns = 'Seed Score (v1)', values = 'prop_guides')

#remove non-targeting
plot_df = plot_df[plot_df.index != 'non-targeting'].copy()

plot_df.plot(kind='bar', stacked=True, cmap = 'Reds')
plt.legend(title = 'Seed Score', fontsize=10, title_fontsize=12, bbox_to_anchor = [1,1])
plt.ylabel('Proportion of guides',fontsize=14)
plt.xlabel('Guide Type',fontsize=14)
plt.xticks(rotation=0,fontsize=12)
plt.yticks(fontsize=10)
plt.title('Katsano Guide Seed Scores',fontsize=14)

sns.despine()
gpp.savefig('../../Figures/Figure 7/katsano_targeting_vs_control_seed_scores_resampled_onesites.pdf',bbox_inches='tight',dpi=300)

# %%
#how many targeting guides have >10 CFD100 off-target sites?
katsano_targeting.loc[katsano_targeting['Off-Target CFD100 Hits'] > 10,'sgRNA Sequence'].nunique()
# Out:
# 28

# %%
#how many TSSs have 4 guides with >10 cfd100 ots, 3, etc?
katsano_targeting.loc[katsano_targeting['Off-Target CFD100 Hits'] > 10,'Input'].value_counts().value_counts()
# Out:
# 4    11
# 2    10
# 1     5
# 3     3
# Name: Input, dtype: int64

# %%
#merge with transcript annotations to determine which genes these are
selected_transcripts_protein_coding = pd.read_csv('../../Data/Katsano/katsano_selected_transcripts.txt')
selected_transcripts_protein_coding['coordinates'] = (selected_transcripts_protein_coding['seqid'] + ':' +
                                                      selected_transcripts_protein_coding['strand'] + ':' +
                                                      selected_transcripts_protein_coding['TSS'].astype(str))
katsano_targeting_annotated = katsano_targeting.merge(selected_transcripts_protein_coding[['coordinates','gene_id','gene_name','Selection Category']].drop_duplicates(),
                                                   left_on = 'Input', right_on = 'coordinates', how = 'inner').reset_index(drop=True)
katsano_targeting_annotated.loc[katsano_targeting_annotated['Off-Target CFD100 Hits'] > 10,'gene_id'].value_counts().value_counts()
# Out:
# 4    11
# 2    10
# 1     5
# 3     3
# Name: gene_id, dtype: int64

# %%
#filter guides with >10 CFD100 off-target sites, since we observed a significant association between >10 CFD100 off-target sites and guide promiscuity
katsano_targeting_filtered = katsano_targeting[katsano_targeting['Off-Target CFD100 Hits'] <= 10]
katsano_targeting_filtered
# Out:
#                    Input  Quota  Target Taxon  Target Gene ID  \
# 0           chr1:+:65419    4.0          9606             NaN
# 1           chr1:+:65419    4.0          9606             NaN
# 2           chr1:+:65419    4.0          9606             NaN
# 3           chr1:+:65419    4.0          9606             NaN
# 21         chr1:-:451678    4.0          9606             NaN
# ...                  ...    ...           ...             ...
# 1734943   chrY:+:1615164    4.0          9606             NaN
# 1734999  chrY:+:25622162    4.0          9606             NaN
# 1735000  chrY:+:25622162    4.0          9606             NaN
# 1735001  chrY:+:25622162    4.0          9606             NaN
# 1735002  chrY:+:25622162    4.0          9606             NaN
#
#          Target Gene Symbol     Target Alias CRISPR Mechanism  \
# 0                       NaN     chr1:+:65419          CRISPRi
# 1                       NaN     chr1:+:65419          CRISPRi
# ...

# %%
#subset to top 3 guides per gene
#there is no need to consider any guides with pick order = 4 because if any guides picked in positions 1-3 for a specific target were
    #removed due to have >10 off-target sites, the fourth pick would have also had >10 off-target sites since that is the last criterion relaxed
katsano_3guide = katsano_targeting_filtered[katsano_targeting_filtered['Pick Order'] <= 3]

#new number of guides per TSS
katsano_3guide['Input'].value_counts().value_counts()
# Out:
# 3    21925
# 2       10
# 1        3
# Name: Input, dtype: int64

# %%
#save original picks for Ensembl Canonical TSSs
katsano_targeting_annotated[['sgRNA Sequence',
                             'gene_id',
                             'gene_name',
                             'Selection Category',
                             'Pick Order']].to_csv('../../Data/Katsano/katsano_4_guide_per_tss_designs.csv',index=False)

# %% [markdown]
# ### Format 6 Column File

# %%
#read in file with gene/transcript annotations
selected_transcripts_protein_coding = pd.read_csv('../../Data/Katsano/katsano_selected_transcripts.txt')
#create column with coordinates to merge on
selected_transcripts_protein_coding['coordinates'] = (selected_transcripts_protein_coding['seqid'] + ':' +
                                                      selected_transcripts_protein_coding['strand'] + ':' +
                                                      selected_transcripts_protein_coding['TSS'].astype(str))

# %%
#merge katsano 3 guide designs with annotations
katsano_targeting_annotated = katsano_3guide.merge(selected_transcripts_protein_coding[['coordinates','gene_id','gene_name']].drop_duplicates(),
                                                   left_on = 'Input', right_on = 'coordinates', how = 'inner').reset_index(drop=True)
katsano_targeting_annotated
# Out:
#                  Input  Quota  Target Taxon  Target Gene ID  \
# 0         chr1:+:65419    4.0          9606             NaN
# 1         chr1:+:65419    4.0          9606             NaN
# 2         chr1:+:65419    4.0          9606             NaN
# 3        chr1:-:451678    4.0          9606             NaN
# 4        chr1:-:451678    4.0          9606             NaN
# ...                ...    ...           ...             ...
# 66075   chrY:+:1615164    4.0          9606             NaN
# 66076   chrY:+:1615164    4.0          9606             NaN
# 66077  chrY:+:25622162    4.0          9606             NaN
# 66078  chrY:+:25622162    4.0          9606             NaN
# 66079  chrY:+:25622162    4.0          9606             NaN
#
#        Target Gene Symbol     Target Alias CRISPR Mechanism     Target Domain  \
# 0                     NaN     chr1:+:65419          CRISPRi  [TSS-50,TSS+300]
# 1                     NaN     chr1:+:65419          CRISPRi  [TSS-50,TSS+300]
# ...

# %%
#number of genes with multiple TSSs targeted with unique sets of guides?
katsano_targeting_annotated['num_tss_targeted'] = katsano_targeting_annotated.groupby('gene_id')['Input'].transform('nunique')
katsano_one_target_genes = katsano_targeting_annotated[katsano_targeting_annotated['num_tss_targeted'] == 1].copy()
katsano_one_target_genes.groupby('gene_id')['sgRNA Sequence'].nunique().value_counts()
# Out:
# 3    18171
# 2        8
# 1        3
# Name: sgRNA Sequence, dtype: int64

# %%
katsano_two_target_genes = katsano_targeting_annotated[katsano_targeting_annotated['num_tss_targeted'] == 2].copy()
katsano_two_target_genes.groupby('gene_id')['sgRNA Sequence'].nunique().value_counts()
# Out:
# 6    907
# 3    421
# 4    380
# 5    214
# Name: sgRNA Sequence, dtype: int64

# %%
907 + 380 + 214
# Out:
# 1501

# %%
katsano_three_target_genes = katsano_targeting_annotated[katsano_targeting_annotated['num_tss_targeted'] == 3].copy()
katsano_three_target_genes.groupby('gene_id')['sgRNA Sequence'].nunique().value_counts()
# Out:
# 7    1
# 9    1
# Name: sgRNA Sequence, dtype: int64

# %%
#rename columns
katsano_targeting_6col = katsano_targeting_annotated[['sgRNA Sequence','gene_id','gene_name']].rename(columns = {'gene_id':'Target Gene ID',
                                                                                                                 'gene_name':'Target Gene Symbol'})
katsano_controls['Target Gene ID'] = np.where(katsano_controls['guide_group'] == 'non-targeting',
                                              'NO_SITE','ONE_INTERGENIC')
katsano_controls['Target Gene Symbol'] = katsano_controls['Target Gene ID']
katsano_controls_6col = katsano_controls.drop('guide_group',axis=1)

#combine targeting and control guides
katsano_6col = pd.concat([katsano_targeting_6col,katsano_controls_6col]).reset_index(drop=True)

#drop duplicate guide sequences
katsano_6col = katsano_6col.drop_duplicates('sgRNA Sequence').reset_index(drop=True)

#add additional columns
katsano_6col['Subpool Name'] = 'Katsano 3-guide'
katsano_6col['Target Taxon'] = 9606
katsano_6col['CRISPR Mechanism'] = 'CRISPRi'

katsano_6col = katsano_6col[['Subpool Name','Target Taxon','CRISPR Mechanism','Target Gene ID','Target Gene Symbol','sgRNA Sequence']]
katsano_6col
# Out:
#           Subpool Name  Target Taxon CRISPR Mechanism     Target Gene ID  \
# 0      Katsano 3-guide          9606          CRISPRi  ENSG00000186092.7
# 1      Katsano 3-guide          9606          CRISPRi  ENSG00000186092.7
# 2      Katsano 3-guide          9606          CRISPRi  ENSG00000186092.7
# 3      Katsano 3-guide          9606          CRISPRi  ENSG00000284733.2
# 4      Katsano 3-guide          9606          CRISPRi  ENSG00000284733.2
# ...                ...           ...              ...                ...
# 63399  Katsano 3-guide          9606          CRISPRi     ONE_INTERGENIC
# 63400  Katsano 3-guide          9606          CRISPRi     ONE_INTERGENIC
# 63401  Katsano 3-guide          9606          CRISPRi     ONE_INTERGENIC
# 63402  Katsano 3-guide          9606          CRISPRi     ONE_INTERGENIC
# 63403  Katsano 3-guide          9606          CRISPRi     ONE_INTERGENIC
#
#       Target Gene Symbol        sgRNA Sequence
# ...

# %%
#check for duplicates
katsano_6col['sgRNA Sequence'].duplicated().sum()
# Out:
# 0

# %%
katsano_6col['Target Gene Symbol'].value_counts().value_counts()
# Out:
# 3      18096
# 6        847
# 4        389
# 5        216
# 2        125
# 1        121
# 9          3
# 900        1
# 100        1
# Name: Target Gene Symbol, dtype: int64

# %%
katsano_6col.to_csv('../../Data/Katsano/katsano_6col.csv',index=False)

# %% [markdown]
# ### Create chip file
# The annotations in selected_transcripts_protein_coding indicate the transcript that each Katsano guide was chosen to target. During analysis, we will want to map each guide to every target it is proximal to.

# %%
all_possible_guides_per_target = katsano_designs[['sgRNA Sequence','Input']].drop_duplicates()
all_possible_guides_per_target
# Out:
#                sgRNA Sequence          Input
# 0        ACATCTAGTCCATTCATAAA   chr1:+:65419
# 1        TACATCTAGTCCATTCATAA   chr1:+:65419
# 2        AATGAGATGGTTCTATTAGT   chr1:+:65419
# 3        AGATGTACCTGAAGAGATCT   chr1:+:65419
# 4        TAGATGTACCTGAAGAGATC   chr1:+:65419
# ...                       ...            ...
# 1736036  AATGTTAGGGTAGACAATAT  (NEG_CONTROL)
# 1736037  CAGGACCTTGAGTAGCACGT  (NEG_CONTROL)
# 1736038  ATAGACTGGTACCCATCCAT  (NEG_CONTROL)
# 1736039  ATAGGCACTTACATAGATCC  (NEG_CONTROL)
# 1736040  GCTGATCAGAGTCCCCCGTA  (NEG_CONTROL)
#
# [1733835 rows x 2 columns]

# %%
#merge katsano 3 guide designs with annotations again, this time including additional columns
katsano_targeting_annotated = katsano_3guide.merge(selected_transcripts_protein_coding[['coordinates','gene_id','gene_name','Selection Category']].drop_duplicates(),
                                                   left_on = 'Input', right_on = 'coordinates', how = 'inner').reset_index(drop=True)
katsano_targeting_annotated
# Out:
#                  Input  Quota  Target Taxon  Target Gene ID  \
# 0         chr1:+:65419    4.0          9606             NaN
# 1         chr1:+:65419    4.0          9606             NaN
# 2         chr1:+:65419    4.0          9606             NaN
# 3        chr1:-:451678    4.0          9606             NaN
# 4        chr1:-:451678    4.0          9606             NaN
# ...                ...    ...           ...             ...
# 66075   chrY:+:1615164    4.0          9606             NaN
# 66076   chrY:+:1615164    4.0          9606             NaN
# 66077  chrY:+:25622162    4.0          9606             NaN
# 66078  chrY:+:25622162    4.0          9606             NaN
# 66079  chrY:+:25622162    4.0          9606             NaN
#
#        Target Gene Symbol     Target Alias CRISPR Mechanism     Target Domain  \
# 0                     NaN     chr1:+:65419          CRISPRi  [TSS-50,TSS+300]
# 1                     NaN     chr1:+:65419          CRISPRi  [TSS-50,TSS+300]
# ...

# %%
tss_gene_mapping = katsano_targeting_annotated[['Input','gene_id','gene_name','Selection Category']].drop_duplicates()
tss_gene_mapping
# Out:
#                   Input             gene_id gene_name  \
# 0          chr1:+:65419   ENSG00000186092.7     OR4F5
# 3         chr1:-:451678   ENSG00000284733.2    OR4F29
# 6         chr1:-:686654   ENSG00000284662.2    OR4F16
# 9         chr1:+:923923  ENSG00000187634.13    SAMD11
# 12        chr1:-:959256  ENSG00000188976.11     NOC2L
# ...                 ...                 ...       ...
# 66065  chrX:-:152709265   ENSG00000268902.5     CSAG2
# 66068     chrY:-:318798   ENSG00000292358.2    GTPBP6
# 66071    chrY:+:1268830   ENSG00000292357.2    CSF2RA
# 66074    chrY:+:1615164   ENSG00000292336.1      ASMT
# 66077   chrY:+:25622162   ENSG00000172288.8      CDY1
#
#                  Selection Category
# 0                 Ensembl Canonical
# 3                 Ensembl Canonical
# 6                 Ensembl Canonical
# 9                 Ensembl Canonical
# 12                Ensembl Canonical
# ...                             ...
# 66065  Closest to Illumina Selected
# ...

# %%
#combine tss/gene/sgRNA annotations into one dataframe
guide_tss_gene_mapping = tss_gene_mapping.merge(all_possible_guides_per_target, on = 'Input', how = 'inner')
guide_tss_gene_mapping
# Out:
#                    Input            gene_id gene_name  \
# 0           chr1:+:65419  ENSG00000186092.7     OR4F5
# 1           chr1:+:65419  ENSG00000186092.7     OR4F5
# 2           chr1:+:65419  ENSG00000186092.7     OR4F5
# 3           chr1:+:65419  ENSG00000186092.7     OR4F5
# 4           chr1:+:65419  ENSG00000186092.7     OR4F5
# ...                  ...                ...       ...
# 1739522  chrY:+:25622162  ENSG00000172288.8      CDY1
# 1739523  chrY:+:25622162  ENSG00000172288.8      CDY1
# 1739524  chrY:+:25622162  ENSG00000172288.8      CDY1
# 1739525  chrY:+:25622162  ENSG00000172288.8      CDY1
# 1739526  chrY:+:25622162  ENSG00000172288.8      CDY1
#
#                    Selection Category        sgRNA Sequence
# 0                   Ensembl Canonical  ACATCTAGTCCATTCATAAA
# 1                   Ensembl Canonical  TACATCTAGTCCATTCATAA
# 2                   Ensembl Canonical  AATGAGATGGTTCTATTAGT
# 3                   Ensembl Canonical  AGATGTACCTGAAGAGATCT
# ...

# %%
#subset to guides in katsano
katsano_targeting_chip = guide_tss_gene_mapping[guide_tss_gene_mapping['sgRNA Sequence'].isin(katsano_targeting_annotated['sgRNA Sequence'])].copy()
katsano_targeting_chip = katsano_targeting_chip.rename(columns = {'Input':'TSS Coordinate',
                                                                  'gene_id':'Target Gene ID',
                                                                  'gene_name':'Target Gene Symbol'})
katsano_targeting_chip
# Out:
#           TSS Coordinate     Target Gene ID Target Gene Symbol  \
# 0           chr1:+:65419  ENSG00000186092.7              OR4F5
# 1           chr1:+:65419  ENSG00000186092.7              OR4F5
# 2           chr1:+:65419  ENSG00000186092.7              OR4F5
# 5           chr1:+:65419  ENSG00000186092.7              OR4F5
# 9           chr1:+:65419  ENSG00000186092.7              OR4F5
# ...                  ...                ...                ...
# 1739486  chrY:+:25622162  ENSG00000172288.8               CDY1
# 1739487  chrY:+:25622162  ENSG00000172288.8               CDY1
# 1739493  chrY:+:25622162  ENSG00000172288.8               CDY1
# 1739497  chrY:+:25622162  ENSG00000172288.8               CDY1
# 1739505  chrY:+:25622162  ENSG00000172288.8               CDY1
#
#                    Selection Category        sgRNA Sequence
# 0                   Ensembl Canonical  ACATCTAGTCCATTCATAAA
# 1                   Ensembl Canonical  TACATCTAGTCCATTCATAA
# ...

# %%
katsano_controls_chip = katsano_controls.drop(['guide_group','seed_seq','Seed Score (v1)'],axis=1)
katsano_controls_chip['TSS Coordinate'] = np.nan
katsano_controls_chip['Selection Category'] = 'Negative Control'
katsano_controls_chip
# Out:
#            sgRNA Sequence  Target Gene ID Target Gene Symbol  TSS Coordinate  \
# 0    CAACGTCGCGAACGTCGTAT         NO_SITE            NO_SITE             NaN
# 1    ACCACCGTTCGTACCGGTCG         NO_SITE            NO_SITE             NaN
# 2    AGACCGTCGTCGATCGATAC         NO_SITE            NO_SITE             NaN
# 3    GTCGTACGGATTCGCGCGTA         NO_SITE            NO_SITE             NaN
# 4    CCCCGATCTTACGTCGCGTA         NO_SITE            NO_SITE             NaN
# ..                    ...             ...                ...             ...
# 995  GTATACACAGGGGTATATAC  ONE_INTERGENIC     ONE_INTERGENIC             NaN
# 996  TCTGAATAGGGGCTACGATA  ONE_INTERGENIC     ONE_INTERGENIC             NaN
# 997  GTATCATTGGGACTAATGGT  ONE_INTERGENIC     ONE_INTERGENIC             NaN
# 998  CATATATGGGGACTCAATGG  ONE_INTERGENIC     ONE_INTERGENIC             NaN
# 999  TAATTCATGGGGCTATCATA  ONE_INTERGENIC     ONE_INTERGENIC             NaN
#
#     Selection Category
# ...

# %%
katsano_chip = pd.concat([katsano_targeting_chip,katsano_controls_chip]).reset_index(drop=True)
katsano_chip
# Out:
#       TSS Coordinate     Target Gene ID Target Gene Symbol Selection Category  \
# 0       chr1:+:65419  ENSG00000186092.7              OR4F5  Ensembl Canonical
# 1       chr1:+:65419  ENSG00000186092.7              OR4F5  Ensembl Canonical
# 2       chr1:+:65419  ENSG00000186092.7              OR4F5  Ensembl Canonical
# 3       chr1:+:65419  ENSG00000186092.7              OR4F5  Ensembl Canonical
# 4       chr1:+:65419  ENSG00000186092.7              OR4F5  Ensembl Canonical
# ...              ...                ...                ...                ...
# 71989            NaN     ONE_INTERGENIC     ONE_INTERGENIC   Negative Control
# 71990            NaN     ONE_INTERGENIC     ONE_INTERGENIC   Negative Control
# 71991            NaN     ONE_INTERGENIC     ONE_INTERGENIC   Negative Control
# 71992            NaN     ONE_INTERGENIC     ONE_INTERGENIC   Negative Control
# 71993            NaN     ONE_INTERGENIC     ONE_INTERGENIC   Negative Control
#
#              sgRNA Sequence
# ...

# %%
katsano_chip.to_csv('../../Data/Katsano/katsano_guide_gene_mapping_GENCODE48.csv',index=False)

# %%
katsano_chip = pd.read_csv('../../Data/Katsano/katsano_guide_gene_mapping_GENCODE48.csv')
katsano_chip['Target Gene ID'].nunique()
# Out:
# 20108
